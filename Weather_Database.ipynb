# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import scipy.stats as linregress
from datetime import datetime
from citipy import citipy
from config import g_key
from config import weather_api_key

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(-90,90,size=9000)
lngs = np.random.uniform(-180,180,size=9000)

#Pair them together
pts = zip(lats,lngs)
pts

#Save the coordinates in a list
city_list = list(pts)

# %%
#Get the nearest city

## Create a list for holding the cities
cities = []

##Get the nearest cities from the city list
for item in city_list:
    city = citipy.nearest_city(item[0],item[1]).city_name

    ## Save new cities in the list
    if city not in cities:
        cities.append(city)

## Print the city count to confirm sufficient count
len(cities)
# Out:
# 2103

# %%
#Perform API call with OpenWeatherMap

## Create an empty list to hold the OpenWeatherMap data for the cities
city_data = []

##Print the beginning of teh logging
print('Beginning data retrieval')
print('-------------------------')

## Create counters for logging purposes
record_count = 1

## Starting / basic URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

## Loop through the cities in our list
for i, city in enumerate(cities):
        
    ## Create an endpoint URL for each city
    city_url = url + '&q=' + city.replace(' ','+')
      
    ## Log the url generation step
    print(f'Processing record {record_count} | {city}')
        
    ## Add 1 to the record count
    record_count +=1

    ## Retrieve OpenWeatherData
    try:
        city_weather = requests.get(city_url).json()
        ### Parse out the relevant data
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lon = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind_speed = city_weather['wind']['speed']
        city_weather_description = city_weather['weather'][0]['description']
        ### Put the data in a dataframe
        city_data.append({'City':city,
                          'Country':city_country,
                          'Lat':city_lat,
                          'Lon':city_lon,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind_speed,
                          'Current Description': city_weather_description
                         })
        
    ## If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        
## Indicate that data retrieval is complete
print('-----------------------------')
print('Data Retrieval Complete      ')
print('-----------------------------')
# Out:
# Beginning data retrieval
# -------------------------
# Processing record 1 | mataura
# Processing record 2 | punta arenas
# Processing record 3 | saldanha
# Processing record 4 | rikitea
# Processing record 5 | east london
# Processing record 6 | sentyabrskiy
# City not found. Skipping...
# Processing record 7 | pitimbu
# Processing record 8 | kruisfontein
# Processing record 9 | arraial do cabo
# Processing record 10 | taunggyi
# Processing record 11 | nizhneyansk
# City not found. Skipping...
# Processing record 12 | osinki
# Processing record 13 | jamestown
# Processing record 14 | torbay
# Processing record 15 | saleaula
# City not found. Skipping...
# Processing record 16 | shieli
# Processing record 17 | geraldton
# Processing record 18 | saskylakh
# Processing record 19 | aksu
# Processing record 20 | usinsk
# Processing record 21 | esperance
# Processing record 22 | bur gabo
# City not found. Skipping...
# Processing record 23 | leningradskiy
# Processing record 24 | atuona
# Processing record 25 | rock sound
# Processing record 26 | toliary
# City not found. Skipping...
# Processing record 27 | barawe
# City not found. Skipping...
# Processing record 28 | albany
# Processing record 29 | butaritari
# Processing record 30 | kapaa
# Processing record 31 | hermanus
# Processing record 32 | kokstad
# Processing record 33 | san patricio
# Processing record 34 | flin flon
# Processing record 35 | taolanaro
# City not found. Skipping...
# Processing record 36 | bonthe
# Processing record 37 | luganville
# Processing record 38 | avarua
# Processing record 39 | yellowknife
# Processing record 40 | codrington
# Processing record 41 | moussoro
# Processing record 42 | saint anthony
# Processing record 43 | illoqqortoormiut
# City not found. Skipping...
# Processing record 44 | port alfred
# Processing record 45 | te anau
# Processing record 46 | tumannyy
# City not found. Skipping...
# Processing record 47 | erzin
# Processing record 48 | barrow
# Processing record 49 | provideniya
# Processing record 50 | touros
# Processing record 51 | cape town
# Processing record 52 | bathsheba
# Processing record 53 | sao miguel do araguaia
# Processing record 54 | lompoc
# Processing record 55 | hobart
# Processing record 56 | barcelona
# Processing record 57 | port hedland
# Processing record 58 | severo-kurilsk
# Processing record 59 | astana
# Processing record 60 | nikolskoye
# Processing record 61 | kirakira
# Processing record 62 | hilo
# Processing record 63 | bredasdorp
# Processing record 64 | olinda
# Processing record 65 | hebi
# Processing record 66 | tomatlan
# Processing record 67 | hithadhoo
# Processing record 68 | yaan
# Processing record 69 | vaini
# Processing record 70 | shimoda
# Processing record 71 | birjand
# Processing record 72 | lensk
# Processing record 73 | timra
# Processing record 74 | khatanga
# Processing record 75 | faanui
# Processing record 76 | busselton
# Processing record 77 | tanshui
# City not found. Skipping...
# Processing record 78 | clyde river
# Processing record 79 | shestakovo
# Processing record 80 | qaanaaq
# Processing record 81 | santa cruz
# Processing record 82 | port lincoln
# Processing record 83 | vestmannaeyjar
# Processing record 84 | houma
# Processing record 85 | lodwar
# Processing record 86 | altona
# Processing record 87 | mar del plata
# Processing record 88 | gustavo diaz ordaz
# Processing record 89 | saint george
# Processing record 90 | bluff
# Processing record 91 | satitoa
# City not found. Skipping...
# Processing record 92 | pevek
# Processing record 93 | kumphawapi
# Processing record 94 | ponta do sol
# Processing record 95 | huarmey
# Processing record 96 | tuktoyaktuk
# Processing record 97 | armizonskoye
# Processing record 98 | morondava
# Processing record 99 | mecca
# Processing record 100 | carnarvon
# Processing record 101 | kamenka
# Processing record 102 | orange
# Processing record 103 | kanigoro
# Processing record 104 | hendijan
# City not found. Skipping...
# Processing record 105 | ushuaia
# Processing record 106 | faya
# Processing record 107 | dabakala
# Processing record 108 | ponta delgada
# Processing record 109 | kodiak
# Processing record 110 | murgab
# Processing record 111 | tasiilaq
# Processing record 112 | rabo de peixe
# Processing record 113 | guymon
# Processing record 114 | kavieng
# Processing record 115 | puerto ayora
# Processing record 116 | tiksi
# Processing record 117 | biak
# Processing record 118 | nouakchott
# Processing record 119 | tabas
# Processing record 120 | martapura
# Processing record 121 | joensuu
# Processing record 122 | nantucket
# Processing record 123 | palana
# Processing record 124 | henties bay
# Processing record 125 | marsh harbour
# Processing record 126 | airai
# Processing record 127 | ferme-neuve
# Processing record 128 | vao
# Processing record 129 | upernavik
# Processing record 130 | hirara
# Processing record 131 | mandalgovi
# Processing record 132 | samusu
# City not found. Skipping...
# Processing record 133 | ribeira grande
# Processing record 134 | kenai
# Processing record 135 | kaitangata
# Processing record 136 | ostrovnoy
# Processing record 137 | rondonopolis
# Processing record 138 | turukhansk
# Processing record 139 | moose factory
# Processing record 140 | sept-iles
# Processing record 141 | san andres
# Processing record 142 | batagay
# Processing record 143 | horni plana
# Processing record 144 | kangaatsiaq
# Processing record 145 | harseni
# Processing record 146 | castro
# Processing record 147 | savannah bight
# Processing record 148 | cagsiay
# Processing record 149 | vardo
# Processing record 150 | giyani
# Processing record 151 | lubao
# Processing record 152 | homer
# Processing record 153 | palmer
# Processing record 154 | nome
# Processing record 155 | leczna
# Processing record 156 | longyearbyen
# Processing record 157 | broken hill
# Processing record 158 | tessalit
# Processing record 159 | cap malheureux
# Processing record 160 | nguiu
# City not found. Skipping...
# Processing record 161 | mogocha
# Processing record 162 | bezhetsk
# Processing record 163 | vostok
# Processing record 164 | college
# Processing record 165 | kamenskoye
# City not found. Skipping...
# Processing record 166 | sibolga
# Processing record 167 | dawson creek
# Processing record 168 | victoria
# Processing record 169 | paradwip
# City not found. Skipping...
# Processing record 170 | chokurdakh
# Processing record 171 | fortuna
# Processing record 172 | port blair
# Processing record 173 | buqayq
# City not found. Skipping...
# Processing record 174 | tibiri
# Processing record 175 | sharjah
# Processing record 176 | christchurch
# Processing record 177 | sao filipe
# Processing record 178 | nishihara
# Processing record 179 | barentsburg
# City not found. Skipping...
# Processing record 180 | belushya guba
# City not found. Skipping...
# Processing record 181 | cherskiy
# Processing record 182 | zhangye
# Processing record 183 | gamba
# Processing record 184 | kieta
# Processing record 185 | cayenne
# Processing record 186 | derzhavinsk
# Processing record 187 | eyl
# Processing record 188 | mahebourg
# Processing record 189 | varnamo
# Processing record 190 | attawapiskat
# City not found. Skipping...
# Processing record 191 | srednekolymsk
# Processing record 192 | nouadhibou
# Processing record 193 | santa rosa
# Processing record 194 | tieli
# Processing record 195 | butembo
# Processing record 196 | linxia
# Processing record 197 | fevralsk
# City not found. Skipping...
# Processing record 198 | san luis obispo
# Processing record 199 | jian
# Processing record 200 | asau
# Processing record 201 | dingle
# Processing record 202 | ginir
# Processing record 203 | kavaratti
# Processing record 204 | new norfolk
# Processing record 205 | hobyo
# Processing record 206 | bengkulu
# Processing record 207 | deputatskiy
# Processing record 208 | alyangula
# Processing record 209 | nuevitas
# Processing record 210 | kochi
# Processing record 211 | mataram
# Processing record 212 | cabo san lucas
# Processing record 213 | paamiut
# Processing record 214 | cidreira
# Processing record 215 | kondoa
# Processing record 216 | lebu
# Processing record 217 | amderma
# City not found. Skipping...
# Processing record 218 | bethel
# Processing record 219 | norman wells
# Processing record 220 | harper
# Processing record 221 | sao paulo de olivenca
# Processing record 222 | kabo
# Processing record 223 | ermoupolis
# Processing record 224 | cururupu
# Processing record 225 | saint-philippe
# Processing record 226 | yerkoy
# Processing record 227 | hasaki
# Processing record 228 | rio grande
# Processing record 229 | jiazi
# Processing record 230 | talara
# Processing record 231 | salalah
# Processing record 232 | casper
# Processing record 233 | sorong
# Processing record 234 | beyneu
# Processing record 235 | nabire
# Processing record 236 | najran
# Processing record 237 | mys shmidta
# City not found. Skipping...
# Processing record 238 | lagoa
# Processing record 239 | pacific grove
# Processing record 240 | komsomolskiy
# Processing record 241 | launceston
# Processing record 242 | kutum
# Processing record 243 | muyezerskiy
# Processing record 244 | carauari
# Processing record 245 | niquelandia
# Processing record 246 | yakeshi
# Processing record 247 | porto novo
# Processing record 248 | taltal
# Processing record 249 | gayny
# Processing record 250 | monkey bay
# Processing record 251 | bafia
# Processing record 252 | valle hermoso
# Processing record 253 | oktyabrskiy
# Processing record 254 | pimentel
# Processing record 255 | ballina
# Processing record 256 | seoul
# Processing record 257 | motygino
# Processing record 258 | sembe
# Processing record 259 | caravelas
# Processing record 260 | sertanopolis
# Processing record 261 | sidi ali
# Processing record 262 | tarakan
# Processing record 263 | atar
# Processing record 264 | los algarrobos
# Processing record 265 | larsnes
# Processing record 266 | constitucion
# Processing record 267 | camaqua
# Processing record 268 | indianola
# Processing record 269 | boyuibe
# Processing record 270 | lake city
# Processing record 271 | bridlington
# Processing record 272 | palabuhanratu
# City not found. Skipping...
# Processing record 273 | phuket
# Processing record 274 | chuy
# Processing record 275 | ust-kamchatsk
# City not found. Skipping...
# Processing record 276 | coffs harbour
# Processing record 277 | nikki
# Processing record 278 | pavlodar
# Processing record 279 | parakai
# Processing record 280 | georgetown
# Processing record 281 | klaksvik
# Processing record 282 | tsihombe
# City not found. Skipping...
# Processing record 283 | iqaluit
# Processing record 284 | sao joao da barra
# Processing record 285 | pinan
# Processing record 286 | oranjemund
# Processing record 287 | aklavik
# Processing record 288 | dikson
# Processing record 289 | tacuarembo
# Processing record 290 | port elizabeth
# Processing record 291 | halalo
# City not found. Skipping...
# Processing record 292 | biharamulo
# Processing record 293 | kodinsk
# Processing record 294 | adrar
# Processing record 295 | porto belo
# Processing record 296 | margate
# Processing record 297 | vaitupu
# City not found. Skipping...
# Processing record 298 | obihiro
# Processing record 299 | namatanai
# Processing record 300 | saint-georges
# Processing record 301 | hamilton
# Processing record 302 | bela
# Processing record 303 | bandarbeyla
# Processing record 304 | kibaek
# Processing record 305 | gambela
# Processing record 306 | lavrentiya
# Processing record 307 | samana
# Processing record 308 | tarko-sale
# Processing record 309 | vila velha
# Processing record 310 | manavalakurichi
# Processing record 311 | trincomalee
# Processing record 312 | maragogi
# Processing record 313 | karratha
# Processing record 314 | boa vista
# Processing record 315 | honiara
# Processing record 316 | marseille
# Processing record 317 | port hardy
# Processing record 318 | kununurra
# Processing record 319 | meyungs
# City not found. Skipping...
# Processing record 320 | chimore
# Processing record 321 | wattegama
# Processing record 322 | roebourne
# Processing record 323 | tevriz
# Processing record 324 | sorsk
# Processing record 325 | kropotkin
# Processing record 326 | husavik
# Processing record 327 | petauke
# Processing record 328 | tuatapere
# Processing record 329 | saint-augustin
# Processing record 330 | sheridan
# Processing record 331 | buariki
# City not found. Skipping...
# Processing record 332 | san quintin
# Processing record 333 | nizwa
# Processing record 334 | louisbourg
# City not found. Skipping...
# Processing record 335 | creston
# Processing record 336 | wakuya
# Processing record 337 | prince george
# Processing record 338 | luderitz
# Processing record 339 | dataganj
# Processing record 340 | ust-omchug
# Processing record 341 | nowy dwor gdanski
# Processing record 342 | souillac
# Processing record 343 | vinh
# Processing record 344 | ahipara
# Processing record 345 | zabid
# Processing record 346 | merauke
# Processing record 347 | san angelo
# Processing record 348 | ngunguru
# Processing record 349 | thompson
# Processing record 350 | mbandaka
# Processing record 351 | oga
# Processing record 352 | mount isa
# Processing record 353 | zhezkazgan
# Processing record 354 | novonikolayevskiy
# Processing record 355 | mount gambier
# Processing record 356 | lasa
# Processing record 357 | antofagasta
# Processing record 358 | campo
# Processing record 359 | suhbaatar
# Processing record 360 | port-gentil
# Processing record 361 | pierre
# Processing record 362 | verkhnyaya inta
# Processing record 363 | ulaangom
# Processing record 364 | dongsheng
# Processing record 365 | andrelandia
# Processing record 366 | vitim
# Processing record 367 | redmond
# Processing record 368 | filderstadt
# Processing record 369 | tezu
# Processing record 370 | gwadar
# Processing record 371 | alofi
# Processing record 372 | sioux lookout
# Processing record 373 | inhambane
# Processing record 374 | jiuquan
# Processing record 375 | antalaha
# Processing record 376 | jonuta
# Processing record 377 | inderborskiy
# City not found. Skipping...
# Processing record 378 | dolbeau
# City not found. Skipping...
# Processing record 379 | hinesville
# Processing record 380 | coquimbo
# Processing record 381 | biltine
# Processing record 382 | matadi
# Processing record 383 | aflu
# City not found. Skipping...
# Processing record 384 | rocha
# Processing record 385 | sinkat
# City not found. Skipping...
# Processing record 386 | broome
# Processing record 387 | fairbanks
# Processing record 388 | fare
# Processing record 389 | manta
# Processing record 390 | acapulco
# Processing record 391 | concarneau
# Processing record 392 | walla walla
# Processing record 393 | pedernales
# Processing record 394 | cleveland
# Processing record 395 | the valley
# Processing record 396 | hofn
# Processing record 397 | cairns
# Processing record 398 | gold coast
# Processing record 399 | grand gaube
# Processing record 400 | montmagny
# Processing record 401 | galesong
# Processing record 402 | east wenatchee bench
# Processing record 403 | plettenberg bay
# Processing record 404 | buala
# Processing record 405 | saint-pierre
# Processing record 406 | kahului
# Processing record 407 | warqla
# City not found. Skipping...
# Processing record 408 | isangel
# Processing record 409 | tulun
# Processing record 410 | dunedin
# Processing record 411 | gat
# Processing record 412 | yar-sale
# Processing record 413 | lorengau
# Processing record 414 | riyadh
# Processing record 415 | mariental
# Processing record 416 | baker city
# Processing record 417 | mount pleasant
# Processing record 418 | general pico
# Processing record 419 | tres arroyos
# Processing record 420 | bubaque
# Processing record 421 | samalaeulu
# City not found. Skipping...
# Processing record 422 | phan thiet
# Processing record 423 | jabiru
# City not found. Skipping...
# Processing record 424 | riwaka
# Processing record 425 | careiro da varzea
# Processing record 426 | vila franca do campo
# Processing record 427 | saint-joseph
# Processing record 428 | grindavik
# Processing record 429 | namie
# Processing record 430 | odweyne
# Processing record 431 | svarstad
# Processing record 432 | la ronge
# Processing record 433 | whitehorse
# Processing record 434 | arroyo
# Processing record 435 | camacha
# Processing record 436 | narsaq
# Processing record 437 | urdzhar
# City not found. Skipping...
# Processing record 438 | brandon
# Processing record 439 | kolyvan
# Processing record 440 | totness
# Processing record 441 | meulaboh
# Processing record 442 | ormara
# Processing record 443 | hami
# Processing record 444 | diourbel
# Processing record 445 | sao borja
# Processing record 446 | altay
# Processing record 447 | anchorage
# Processing record 448 | develi
# Processing record 449 | mackay
# Processing record 450 | inuvik
# Processing record 451 | havre-saint-pierre
# Processing record 452 | marsa matruh
# Processing record 453 | brae
# Processing record 454 | kuusamo
# Processing record 455 | vargem alta
# Processing record 456 | henzada
# City not found. Skipping...
# Processing record 457 | gorin
# Processing record 458 | bud
# Processing record 459 | north bend
# Processing record 460 | yei
# Processing record 461 | guerrero negro
# Processing record 462 | dawei
# Processing record 463 | kormilovka
# Processing record 464 | tautira
# Processing record 465 | ancud
# Processing record 466 | camalu
# Processing record 467 | cedar city
# Processing record 468 | mizdah
# Processing record 469 | tahe
# Processing record 470 | hongjiang
# Processing record 471 | rawson
# Processing record 472 | miramar
# Processing record 473 | umm lajj
# Processing record 474 | bar harbor
# Processing record 475 | bilgoraj
# Processing record 476 | grand baie
# Processing record 477 | gorodishche
# Processing record 478 | moirang
# Processing record 479 | biloela
# Processing record 480 | farrukhnagar
# Processing record 481 | tiarei
# Processing record 482 | liwale
# Processing record 483 | phan rang
# City not found. Skipping...
# Processing record 484 | asyut
# Processing record 485 | marawi
# Processing record 486 | matara
# Processing record 487 | kichera
# Processing record 488 | haines junction
# Processing record 489 | westport
# Processing record 490 | masuguru
# Processing record 491 | kayes
# Processing record 492 | lephepe
# City not found. Skipping...
# Processing record 493 | genhe
# Processing record 494 | kargasok
# Processing record 495 | hambantota
# Processing record 496 | sakakah
# Processing record 497 | pilar do sul
# Processing record 498 | mallama
# City not found. Skipping...
# Processing record 499 | sturgeon falls
# Processing record 500 | shingu
# Processing record 501 | labuhan
# Processing record 502 | hovd
# Processing record 503 | port-cartier
# Processing record 504 | alta floresta
# Processing record 505 | roma
# Processing record 506 | rio gallegos
# Processing record 507 | talnakh
# Processing record 508 | mocuba
# Processing record 509 | thunder bay
# Processing record 510 | zarichne
# Processing record 511 | dedougou
# Processing record 512 | katsuura
# Processing record 513 | mana
# Processing record 514 | mehamn
# Processing record 515 | ilulissat
# Processing record 516 | bambous virieux
# Processing record 517 | myitkyina
# Processing record 518 | grand river south east
# City not found. Skipping...
# Processing record 519 | camopi
# Processing record 520 | matehuala
# Processing record 521 | dukat
# Processing record 522 | abonnema
# Processing record 523 | aransas pass
# Processing record 524 | richards bay
# Processing record 525 | praia da vitoria
# Processing record 526 | severobaykalsk
# Processing record 527 | san lazaro
# Processing record 528 | avera
# Processing record 529 | pangai
# Processing record 530 | jiddah
# City not found. Skipping...
# Processing record 531 | malinyi
# Processing record 532 | buchanan
# Processing record 533 | tarudant
# City not found. Skipping...
# Processing record 534 | batemans bay
# Processing record 535 | mareeba
# Processing record 536 | rassvet
# Processing record 537 | manyana
# Processing record 538 | lerwick
# Processing record 539 | afogados da ingazeira
# Processing record 540 | ketchikan
# Processing record 541 | half moon bay
# Processing record 542 | samarinda
# Processing record 543 | neiafu
# Processing record 544 | cambridge
# Processing record 545 | kailua
# Processing record 546 | moron
# Processing record 547 | villa sandino
# Processing record 548 | muros
# Processing record 549 | energeticheskiy
# Processing record 550 | garhi khairo
# Processing record 551 | brainerd
# Processing record 552 | pasir gudang
# Processing record 553 | pochutla
# Processing record 554 | san cristobal
# Processing record 555 | ostrov
# Processing record 556 | fort morgan
# Processing record 557 | brownwood
# Processing record 558 | zhuanghe
# Processing record 559 | iralaya
# Processing record 560 | uarini
# Processing record 561 | marystown
# Processing record 562 | lata
# Processing record 563 | ust-maya
# Processing record 564 | egvekinot
# Processing record 565 | asfi
# Processing record 566 | sao miguel do iguacu
# Processing record 567 | cabo rojo
# Processing record 568 | irtyshskiy
# Processing record 569 | arkansas city
# Processing record 570 | solnechnyy
# Processing record 571 | rupert
# Processing record 572 | chapais
# Processing record 573 | vung tau
# Processing record 574 | bagratashen
# Processing record 575 | ukiah
# Processing record 576 | mantua
# Processing record 577 | cherdyn
# Processing record 578 | kampot
# Processing record 579 | tuggurt
# City not found. Skipping...
# Processing record 580 | lokachi
# Processing record 581 | tabalosos
# Processing record 582 | kamennogorsk
# Processing record 583 | goderich
# Processing record 584 | goure
# Processing record 585 | robat karim
# Processing record 586 | sogdiondon
# City not found. Skipping...
# Processing record 587 | pangkalanbuun
# Processing record 588 | hauterive
# Processing record 589 | bahia honda
# Processing record 590 | robertsport
# Processing record 591 | ortigueira
# Processing record 592 | cabra
# Processing record 593 | brightwater
# Processing record 594 | carlagan
# Processing record 595 | hay river
# Processing record 596 | biryusinsk
# Processing record 597 | xiaoweizhai
# Processing record 598 | priargunsk
# Processing record 599 | pecanha
# Processing record 600 | portland
# Processing record 601 | alugan
# Processing record 602 | kuytun
# Processing record 603 | suksun
# Processing record 604 | barra do garcas
# Processing record 605 | macau
# Processing record 606 | umea
# Processing record 607 | bayan
# Processing record 608 | mangaluru
# Processing record 609 | waipawa
# Processing record 610 | yeniseysk
# Processing record 611 | sola
# Processing record 612 | salinopolis
# Processing record 613 | sofiysk
# City not found. Skipping...
# Processing record 614 | aliwal north
# Processing record 615 | betioky
# Processing record 616 | sechura
# Processing record 617 | necochea
# Processing record 618 | yumen
# Processing record 619 | twentynine palms
# Processing record 620 | aitape
# Processing record 621 | mercedes
# Processing record 622 | nemuro
# Processing record 623 | thinadhoo
# Processing record 624 | nelson bay
# Processing record 625 | guacimo
# Processing record 626 | iwanai
# Processing record 627 | susanville
# Processing record 628 | beloha
# Processing record 629 | mbinga
# Processing record 630 | voiteg
# Processing record 631 | panguna
# Processing record 632 | mayo
# Processing record 633 | weligama
# Processing record 634 | leh
# Processing record 635 | hastings
# Processing record 636 | burnie
# Processing record 637 | luan
# Processing record 638 | kudahuvadhoo
# Processing record 639 | ca mau
# Processing record 640 | beisfjord
# Processing record 641 | utete
# Processing record 642 | oktyabrskoye
# Processing record 643 | fukue
# Processing record 644 | skalistyy
# City not found. Skipping...
# Processing record 645 | pata
# Processing record 646 | boshnyakovo
# Processing record 647 | yatou
# Processing record 648 | sindand
# City not found. Skipping...
# Processing record 649 | araouane
# Processing record 650 | makung
# City not found. Skipping...
# Processing record 651 | bababe
# City not found. Skipping...
# Processing record 652 | miri
# Processing record 653 | nanakuli
# Processing record 654 | bauta
# Processing record 655 | eureka
# Processing record 656 | labrea
# Processing record 657 | marsabit
# Processing record 658 | bako
# Processing record 659 | scottsbluff
# Processing record 660 | petropavlovsk-kamchatskiy
# Processing record 661 | nenjiang
# Processing record 662 | hit
# Processing record 663 | piura
# Processing record 664 | sandy bay
# Processing record 665 | balimo
# City not found. Skipping...
# Processing record 666 | bosaso
# Processing record 667 | pangody
# Processing record 668 | karera
# Processing record 669 | lillooet
# Processing record 670 | carutapera
# Processing record 671 | ust-nera
# Processing record 672 | ossora
# Processing record 673 | kidal
# Processing record 674 | nanortalik
# Processing record 675 | ambilobe
# Processing record 676 | santa cruz do rio pardo
# Processing record 677 | sanmenxia
# Processing record 678 | morehead
# Processing record 679 | kinablangan
# Processing record 680 | oyama
# Processing record 681 | tura
# Processing record 682 | new philadelphia
# Processing record 683 | poum
# Processing record 684 | carlsbad
# Processing record 685 | pimenta bueno
# Processing record 686 | laguna
# Processing record 687 | comodoro rivadavia
# Processing record 688 | tucuman
# Processing record 689 | beringovskiy
# Processing record 690 | dzhusaly
# City not found. Skipping...
# Processing record 691 | pilar
# Processing record 692 | tawang
# Processing record 693 | mabaruma
# Processing record 694 | noumea
# Processing record 695 | bethanien
# Processing record 696 | saint-denis
# Processing record 697 | meadow lake
# Processing record 698 | kaabong
# Processing record 699 | marienburg
# Processing record 700 | cockburn town
# Processing record 701 | tomohon
# Processing record 702 | pangnirtung
# Processing record 703 | aleksinac
# Processing record 704 | le port
# Processing record 705 | kimparana
# Processing record 706 | taos
# Processing record 707 | barra patuca
# Processing record 708 | safaga
# Processing record 709 | kemi
# Processing record 710 | tete
# Processing record 711 | cravo norte
# Processing record 712 | zeya
# Processing record 713 | tilichiki
# Processing record 714 | yanam
# Processing record 715 | leeuwarden
# Processing record 716 | maturin
# Processing record 717 | lodja
# Processing record 718 | krasnorechenskiy
# Processing record 719 | gualeguay
# Processing record 720 | colac
# Processing record 721 | marfino
# Processing record 722 | anadyr
# Processing record 723 | pitsunda
# Processing record 724 | mineral wells
# Processing record 725 | zdvinsk
# Processing record 726 | whitianga
# Processing record 727 | san juan
# Processing record 728 | sumbawa
# City not found. Skipping...
# Processing record 729 | tubruq
# City not found. Skipping...
# Processing record 730 | sheregesh
# Processing record 731 | taoudenni
# Processing record 732 | coruripe
# Processing record 733 | sondrio
# Processing record 734 | sungairaya
# Processing record 735 | russell
# Processing record 736 | rio cuarto
# Processing record 737 | kalmunai
# Processing record 738 | soe
# Processing record 739 | sinnamary
# Processing record 740 | lieksa
# Processing record 741 | aksarka
# Processing record 742 | birin
# Processing record 743 | svetlogorsk
# Processing record 744 | daru
# Processing record 745 | affery
# Processing record 746 | challans
# Processing record 747 | dombarovskiy
# Processing record 748 | kaduna
# Processing record 749 | teya
# Processing record 750 | mahenge
# Processing record 751 | jumla
# Processing record 752 | mazyr
# Processing record 753 | victor harbor
# Processing record 754 | kerema
# Processing record 755 | kroonstad
# Processing record 756 | kiama
# Processing record 757 | igatpuri
# Processing record 758 | corumba
# Processing record 759 | paita
# Processing record 760 | maniwaki
# Processing record 761 | zwedru
# Processing record 762 | pisco
# Processing record 763 | sataua
# City not found. Skipping...
# Processing record 764 | lithakia
# Processing record 765 | yulara
# Processing record 766 | olafsvik
# Processing record 767 | vzmorye
# Processing record 768 | newbridge
# Processing record 769 | madras
# Processing record 770 | tallahassee
# Processing record 771 | lalibela
# Processing record 772 | xingcheng
# Processing record 773 | young
# Processing record 774 | bilma
# Processing record 775 | awbari
# Processing record 776 | garowe
# Processing record 777 | buin
# Processing record 778 | aswan
# Processing record 779 | barabai
# Processing record 780 | bereda
# Processing record 781 | qena
# Processing record 782 | vredendal
# Processing record 783 | jiangkou
# Processing record 784 | ndioum
# Processing record 785 | tra vinh
# Processing record 786 | wulanhaote
# City not found. Skipping...
# Processing record 787 | hualmay
# Processing record 788 | zunyi
# Processing record 789 | sovetskiy
# Processing record 790 | severodvinsk
# Processing record 791 | raudeberg
# Processing record 792 | mujiayingzi
# Processing record 793 | moroni
# Processing record 794 | naberera
# Processing record 795 | stavern
# Processing record 796 | omboue
# Processing record 797 | novo aripuana
# Processing record 798 | acajutla
# Processing record 799 | mount darwin
# Processing record 800 | bairiki
# Processing record 801 | kalevala
# Processing record 802 | dongzhen
# Processing record 803 | ozgon
# City not found. Skipping...
# Processing record 804 | naziya
# Processing record 805 | saurimo
# Processing record 806 | bakel
# Processing record 807 | slonim
# Processing record 808 | armacao dos buzios
# City not found. Skipping...
# Processing record 809 | camabatela
# Processing record 810 | diffa
# Processing record 811 | liwonde
# Processing record 812 | standerton
# Processing record 813 | calama
# Processing record 814 | meridian
# Processing record 815 | banda aceh
# Processing record 816 | artyk
# City not found. Skipping...
# Processing record 817 | borujan
# City not found. Skipping...
# Processing record 818 | tukrah
# Processing record 819 | chara
# Processing record 820 | alexandria
# Processing record 821 | ouadda
# Processing record 822 | collie
# Processing record 823 | mwense
# Processing record 824 | alice springs
# Processing record 825 | novospasskoye
# Processing record 826 | kotido
# Processing record 827 | luau
# Processing record 828 | sorland
# Processing record 829 | zhigansk
# Processing record 830 | bella union
# Processing record 831 | kabalo
# Processing record 832 | coahuayana
# Processing record 833 | maniitsoq
# Processing record 834 | cortes
# Processing record 835 | osvaldo cruz
# Processing record 836 | petrolina
# Processing record 837 | tres passos
# Processing record 838 | iracoubo
# Processing record 839 | bage
# Processing record 840 | tortosa
# Processing record 841 | yerbogachen
# Processing record 842 | landang
# City not found. Skipping...
# Processing record 843 | tanout
# Processing record 844 | havelock
# Processing record 845 | palmeira das missoes
# Processing record 846 | raymond
# Processing record 847 | conceicao do araguaia
# Processing record 848 | vilhena
# Processing record 849 | puerto escondido
# Processing record 850 | lokoja
# Processing record 851 | mizpe ramon
# City not found. Skipping...
# Processing record 852 | dolores
# Processing record 853 | baruun-urt
# Processing record 854 | itarema
# Processing record 855 | sydney
# Processing record 856 | rochegda
# Processing record 857 | haibowan
# City not found. Skipping...
# Processing record 858 | port keats
# Processing record 859 | miami
# Processing record 860 | khandyga
# Processing record 861 | porto-vecchio
# Processing record 862 | naantali
# Processing record 863 | bom jesus
# Processing record 864 | chegdomyn
# Processing record 865 | polunochnoye
# Processing record 866 | vossevangen
# Processing record 867 | kushiro
# Processing record 868 | staroutkinsk
# Processing record 869 | yanan
# City not found. Skipping...
# Processing record 870 | dubenskiy
# City not found. Skipping...
# Processing record 871 | charters towers
# Processing record 872 | dali
# Processing record 873 | waddan
# Processing record 874 | dzhebariki-khaya
# Processing record 875 | miyako
# Processing record 876 | okato
# Processing record 877 | kerteh
# City not found. Skipping...
# Processing record 878 | los llanos de aridane
# Processing record 879 | ghanzi
# Processing record 880 | kaputa
# Processing record 881 | roald
# Processing record 882 | quiruvilca
# Processing record 883 | puerto madryn
# Processing record 884 | narasannapeta
# Processing record 885 | benghazi
# Processing record 886 | ardistan
# City not found. Skipping...
# Processing record 887 | that phanom
# Processing record 888 | andijon
# Processing record 889 | ust-ishim
# Processing record 890 | juarez
# Processing record 891 | krasnoarmeysk
# Processing record 892 | formoso do araguaia
# City not found. Skipping...
# Processing record 893 | ulladulla
# Processing record 894 | cam ranh
# Processing record 895 | rungata
# City not found. Skipping...
# Processing record 896 | kemijarvi
# Processing record 897 | santa cruz de tenerife
# Processing record 898 | lingao
# Processing record 899 | seydi
# Processing record 900 | golspie
# Processing record 901 | junin
# Processing record 902 | wolverhampton
# Processing record 903 | dwarka
# Processing record 904 | luanda
# Processing record 905 | bindura
# Processing record 906 | batticaloa
# Processing record 907 | arica
# Processing record 908 | lianran
# Processing record 909 | osoyoos
# Processing record 910 | dharchula
# Processing record 911 | agadir
# Processing record 912 | veraval
# Processing record 913 | muravlenko
# Processing record 914 | gazanjyk
# Processing record 915 | svetlyy
# Processing record 916 | chifeng
# Processing record 917 | zabol
# Processing record 918 | lahat
# Processing record 919 | tongliao
# Processing record 920 | tuy hoa
# Processing record 921 | oskemen
# Processing record 922 | yelizovo
# Processing record 923 | ilhabela
# Processing record 924 | vavuniya
# Processing record 925 | oltu
# Processing record 926 | wichita falls
# Processing record 927 | javanrud
# Processing record 928 | nagarote
# Processing record 929 | santa marta
# Processing record 930 | naze
# Processing record 931 | gejiu
# Processing record 932 | kovernino
# Processing record 933 | rochefort
# Processing record 934 | red wing
# Processing record 935 | jinchang
# Processing record 936 | novokayakent
# Processing record 937 | agirish
# Processing record 938 | blenheim
# Processing record 939 | nizamabad
# Processing record 940 | kpandu
# Processing record 941 | seymchan
# Processing record 942 | puli
# Processing record 943 | puerto del rosario
# Processing record 944 | fukuma
# Processing record 945 | waingapu
# Processing record 946 | buraydah
# Processing record 947 | semey
# Processing record 948 | gushikawa
# Processing record 949 | leirvik
# Processing record 950 | kjollefjord
# Processing record 951 | sawakin
# Processing record 952 | barranca
# Processing record 953 | papetoai
# Processing record 954 | wahpeton
# Processing record 955 | fort nelson
# Processing record 956 | ordu
# Processing record 957 | tambun
# Processing record 958 | bandar-e lengeh
# Processing record 959 | longlac
# City not found. Skipping...
# Processing record 960 | puksoozero
# Processing record 961 | kiunga
# Processing record 962 | nassau
# Processing record 963 | tabou
# Processing record 964 | plavsk
# Processing record 965 | agadez
# Processing record 966 | kysyl-syr
# Processing record 967 | khani
# Processing record 968 | ciudad real
# Processing record 969 | san rafael
# Processing record 970 | la romana
# Processing record 971 | dzaoudzi
# Processing record 972 | gwanda
# Processing record 973 | banjar
# Processing record 974 | valenca do piaui
# Processing record 975 | kumluca
# Processing record 976 | bowen
# Processing record 977 | santa marinella
# Processing record 978 | impfondo
# Processing record 979 | santana do livramento
# Processing record 980 | verkh-usugli
# Processing record 981 | songea
# Processing record 982 | saint simons
# Processing record 983 | jalu
# Processing record 984 | birao
# Processing record 985 | mahendranagar
# Processing record 986 | loandjili
# Processing record 987 | gravelbourg
# Processing record 988 | payo
# Processing record 989 | awjilah
# Processing record 990 | kishi
# Processing record 991 | kurchum
# Processing record 992 | pokaran
# Processing record 993 | hunucma
# Processing record 994 | lishu
# Processing record 995 | kuah
# Processing record 996 | sharlyk
# Processing record 997 | dicabisagan
# Processing record 998 | eirunepe
# Processing record 999 | lufkin
# Processing record 1000 | jacareacanga
# Processing record 1001 | aberdeen
# Processing record 1002 | sherbakul
# Processing record 1003 | viligili
# City not found. Skipping...
# Processing record 1004 | bac lieu
# Processing record 1005 | talcahuano
# Processing record 1006 | bintulu
# Processing record 1007 | jamame
# Processing record 1008 | campbell river
# Processing record 1009 | zaraza
# Processing record 1010 | aligudarz
# Processing record 1011 | padang
# Processing record 1012 | berlevag
# Processing record 1013 | pandan
# Processing record 1014 | dakar
# Processing record 1015 | gornozavodsk
# Processing record 1016 | perth
# Processing record 1017 | bardiyah
# Processing record 1018 | fengrun
# Processing record 1019 | shirokiy
# Processing record 1020 | buzmeyin
# Processing record 1021 | lamar
# Processing record 1022 | santo tomas
# Processing record 1023 | ciudad bolivar
# Processing record 1024 | romanovskaya
# Processing record 1025 | ondorhaan
# City not found. Skipping...
# Processing record 1026 | new iberia
# Processing record 1027 | belaya gora
# Processing record 1028 | la asuncion
# Processing record 1029 | port macquarie
# Processing record 1030 | petushki
# Processing record 1031 | ulagan
# Processing record 1032 | ola
# Processing record 1033 | chabahar
# Processing record 1034 | ushtobe
# Processing record 1035 | nyurba
# Processing record 1036 | korla
# Processing record 1037 | trairi
# Processing record 1038 | xushan
# Processing record 1039 | rezina
# Processing record 1040 | marcona
# City not found. Skipping...
# Processing record 1041 | boysun
# Processing record 1042 | ornskoldsvik
# Processing record 1043 | wahran
# City not found. Skipping...
# Processing record 1044 | xifeng
# Processing record 1045 | uyuni
# Processing record 1046 | kikwit
# Processing record 1047 | virginia beach
# Processing record 1048 | caxito
# Processing record 1049 | whyalla
# Processing record 1050 | chongwe
# Processing record 1051 | sitka
# Processing record 1052 | maceio
# Processing record 1053 | namibe
# Processing record 1054 | valparaiso
# Processing record 1055 | vuktyl
# Processing record 1056 | aquiraz
# Processing record 1057 | ribeira brava
# Processing record 1058 | samarai
# Processing record 1059 | labutta
# City not found. Skipping...
# Processing record 1060 | iquique
# Processing record 1061 | el faiyum
# City not found. Skipping...
# Processing record 1062 | tamiahua
# Processing record 1063 | byron bay
# Processing record 1064 | chuncheng
# Processing record 1065 | ixtapa
# Processing record 1066 | stoyba
# City not found. Skipping...
# Processing record 1067 | keti bandar
# Processing record 1068 | jieshi
# Processing record 1069 | mombetsu
# Processing record 1070 | knokke-heist
# Processing record 1071 | mosquera
# Processing record 1072 | sloboda
# Processing record 1073 | la palma
# Processing record 1074 | uvat
# Processing record 1075 | muli
# Processing record 1076 | tabiauea
# City not found. Skipping...
# Processing record 1077 | kanniyakumari
# Processing record 1078 | maloshuyka
# City not found. Skipping...
# Processing record 1079 | sicuani
# Processing record 1080 | oranjestad
# Processing record 1081 | pemangkat
# Processing record 1082 | hurghada
# Processing record 1083 | lanigan
# Processing record 1084 | guisa
# Processing record 1085 | lethem
# Processing record 1086 | neuquen
# Processing record 1087 | bam
# Processing record 1088 | rolim de moura
# City not found. Skipping...
# Processing record 1089 | placido de castro
# Processing record 1090 | atagay
# Processing record 1091 | luwuk
# Processing record 1092 | sao felix do xingu
# Processing record 1093 | belmonte
# Processing record 1094 | san pedro
# Processing record 1095 | yian
# City not found. Skipping...
# Processing record 1096 | camacupa
# Processing record 1097 | ozinki
# Processing record 1098 | tuzha
# Processing record 1099 | grenada
# Processing record 1100 | kracheh
# City not found. Skipping...
# Processing record 1101 | mityana
# Processing record 1102 | nhulunbuy
# Processing record 1103 | noshiro
# Processing record 1104 | caorle
# Processing record 1105 | cabedelo
# Processing record 1106 | chaman
# Processing record 1107 | abnub
# Processing record 1108 | nara
# Processing record 1109 | mpongwe
# Processing record 1110 | gizo
# Processing record 1111 | el bagre
# Processing record 1112 | banyo
# Processing record 1113 | atambua
# Processing record 1114 | tala
# Processing record 1115 | phayao
# Processing record 1116 | tromso
# Processing record 1117 | kamyaran
# Processing record 1118 | bjornevatn
# Processing record 1119 | ruatoria
# City not found. Skipping...
# Processing record 1120 | agapovka
# Processing record 1121 | marechal candido rondon
# Processing record 1122 | vila
# Processing record 1123 | keflavik
# Processing record 1124 | camargo
# Processing record 1125 | kimbe
# Processing record 1126 | horta
# Processing record 1127 | sena madureira
# Processing record 1128 | port ellen
# City not found. Skipping...
# Processing record 1129 | amparai
# City not found. Skipping...
# Processing record 1130 | lalmanir hat
# City not found. Skipping...
# Processing record 1131 | vestmanna
# Processing record 1132 | nakambala
# Processing record 1133 | ryotsu
# Processing record 1134 | saraland
# Processing record 1135 | kanlagay
# Processing record 1136 | obo
# Processing record 1137 | bolungarvik
# City not found. Skipping...
# Processing record 1138 | pala
# Processing record 1139 | zhanaozen
# Processing record 1140 | omsukchan
# Processing record 1141 | santiago del estero
# Processing record 1142 | salisbury
# Processing record 1143 | coulihaut
# City not found. Skipping...
# Processing record 1144 | erenhot
# Processing record 1145 | wawa
# Processing record 1146 | manggar
# Processing record 1147 | koumac
# Processing record 1148 | arrecife
# Processing record 1149 | quatre cocos
# Processing record 1150 | umm kaddadah
# Processing record 1151 | zhoucheng
# Processing record 1152 | krasnyy chikoy
# Processing record 1153 | assare
# Processing record 1154 | consett
# Processing record 1155 | golcuk
# City not found. Skipping...
# Processing record 1156 | san vicente
# Processing record 1157 | remiremont
# Processing record 1158 | olbia
# Processing record 1159 | koindu
# Processing record 1160 | atlantic city
# Processing record 1161 | mogok
# Processing record 1162 | tadine
# Processing record 1163 | mongar
# Processing record 1164 | alappuzha
# Processing record 1165 | farmington
# Processing record 1166 | port arthur
# Processing record 1167 | teknaf
# Processing record 1168 | alotau
# City not found. Skipping...
# Processing record 1169 | krasnoborsk
# Processing record 1170 | shahganj
# Processing record 1171 | santa pola
# Processing record 1172 | korgen
# Processing record 1173 | ust-ilimsk
# Processing record 1174 | umzimvubu
# City not found. Skipping...
# Processing record 1175 | kenosha
# Processing record 1176 | cockburn harbour
# City not found. Skipping...
# Processing record 1177 | tual
# Processing record 1178 | glendive
# Processing record 1179 | komatipoort
# Processing record 1180 | aromashevo
# Processing record 1181 | mitu
# Processing record 1182 | krasnoselkup
# Processing record 1183 | suleja
# Processing record 1184 | inta
# Processing record 1185 | siderno
# Processing record 1186 | dvinskoy
# Processing record 1187 | asosa
# Processing record 1188 | les cayes
# Processing record 1189 | taburi
# City not found. Skipping...
# Processing record 1190 | ntoum
# Processing record 1191 | port augusta
# Processing record 1192 | progreso
# Processing record 1193 | davila
# Processing record 1194 | krasnoye
# Processing record 1195 | litayen
# City not found. Skipping...
# Processing record 1196 | tiznit
# Processing record 1197 | santo amaro da imperatriz
# Processing record 1198 | ambodifototra
# City not found. Skipping...
# Processing record 1199 | nuuk
# Processing record 1200 | ji-parana
# City not found. Skipping...
# Processing record 1201 | mochicahui
# Processing record 1202 | leshan
# Processing record 1203 | port moresby
# Processing record 1204 | pozo colorado
# Processing record 1205 | yining
# Processing record 1206 | tayga
# Processing record 1207 | vysokogornyy
# Processing record 1208 | malindi
# Processing record 1209 | milkovo
# Processing record 1210 | talaya
# Processing record 1211 | yangambi
# Processing record 1212 | lewistown
# Processing record 1213 | koluszki
# Processing record 1214 | chachapoyas
# Processing record 1215 | flinders
# Processing record 1216 | pamanukan
# Processing record 1217 | charagua
# Processing record 1218 | sobolevo
# Processing record 1219 | axtla
# City not found. Skipping...
# Processing record 1220 | maxixe
# Processing record 1221 | praia
# Processing record 1222 | ljungby
# Processing record 1223 | kharp
# Processing record 1224 | azimur
# City not found. Skipping...
# Processing record 1225 | bargal
# City not found. Skipping...
# Processing record 1226 | banamba
# Processing record 1227 | mastic beach
# Processing record 1228 | ishim
# Processing record 1229 | vancouver
# Processing record 1230 | tabory
# Processing record 1231 | kapoeta
# Processing record 1232 | katangli
# Processing record 1233 | chalisgaon
# Processing record 1234 | moramanga
# Processing record 1235 | mindelo
# Processing record 1236 | beira
# Processing record 1237 | qinhuangdao
# Processing record 1238 | juneau
# Processing record 1239 | ayan
# Processing record 1240 | shimanovsk
# Processing record 1241 | qaqortoq
# Processing record 1242 | matagami
# Processing record 1243 | solovetskiy
# City not found. Skipping...
# Processing record 1244 | mrirt
# City not found. Skipping...
# Processing record 1245 | manokwari
# Processing record 1246 | laela
# Processing record 1247 | boras
# Processing record 1248 | prince rupert
# Processing record 1249 | borogontsy
# Processing record 1250 | surt
# Processing record 1251 | skibbereen
# Processing record 1252 | rauma
# Processing record 1253 | katobu
# Processing record 1254 | fujinomiya
# Processing record 1255 | wenling
# Processing record 1256 | balykshi
# Processing record 1257 | monrovia
# Processing record 1258 | abay
# Processing record 1259 | stutterheim
# Processing record 1260 | bogorodskoye
# Processing record 1261 | lazarev
# Processing record 1262 | kiruna
# Processing record 1263 | bilibino
# Processing record 1264 | satipo
# Processing record 1265 | benguela
# Processing record 1266 | tyukalinsk
# Processing record 1267 | baft
# Processing record 1268 | chitungwiza
# Processing record 1269 | shellbrook
# Processing record 1270 | darnah
# Processing record 1271 | xining
# Processing record 1272 | ulaanbaatar
# Processing record 1273 | jawhar
# Processing record 1274 | ayorou
# Processing record 1275 | babanusah
# City not found. Skipping...
# Processing record 1276 | betsiamites
# Processing record 1277 | martin
# Processing record 1278 | carahue
# Processing record 1279 | itaituba
# Processing record 1280 | zaysan
# Processing record 1281 | lima
# Processing record 1282 | novopetrovskoye
# Processing record 1283 | mnogovershinnyy
# Processing record 1284 | sartell
# Processing record 1285 | rajapur
# Processing record 1286 | cerrito
# Processing record 1287 | marabba
# Processing record 1288 | othonoi
# City not found. Skipping...
# Processing record 1289 | utinga
# Processing record 1290 | naryan-mar
# Processing record 1291 | pacifica
# Processing record 1292 | salemi
# Processing record 1293 | sape
# Processing record 1294 | basoko
# Processing record 1295 | luangwa
# Processing record 1296 | havre
# Processing record 1297 | elesbao veloso
# Processing record 1298 | sereflikochisar
# Processing record 1299 | severo-yeniseyskiy
# Processing record 1300 | khasan
# Processing record 1301 | el espinal
# Processing record 1302 | amasya
# Processing record 1303 | mundargi
# Processing record 1304 | artigas
# Processing record 1305 | sadove
# Processing record 1306 | iranduba
# Processing record 1307 | huilong
# Processing record 1308 | praya
# Processing record 1309 | camocim
# Processing record 1310 | mitchell
# Processing record 1311 | stornoway
# Processing record 1312 | calvinia
# Processing record 1313 | kupang
# Processing record 1314 | yilan
# Processing record 1315 | preobrazheniye
# Processing record 1316 | mansa
# Processing record 1317 | zarand
# Processing record 1318 | guarapari
# Processing record 1319 | makaha
# Processing record 1320 | muscat
# Processing record 1321 | adliswil
# Processing record 1322 | balclutha
# Processing record 1323 | sur
# Processing record 1324 | huejuquilla el alto
# Processing record 1325 | at-bashi
# Processing record 1326 | acarau
# Processing record 1327 | beroroha
# Processing record 1328 | urgut
# Processing record 1329 | handwara
# City not found. Skipping...
# Processing record 1330 | locri
# Processing record 1331 | bentiu
# Processing record 1332 | makakilo city
# Processing record 1333 | meybod
# Processing record 1334 | san blas
# Processing record 1335 | dmitriyevka
# Processing record 1336 | chitaga
# Processing record 1337 | weihe
# Processing record 1338 | wahiawa
# Processing record 1339 | vaitape
# Processing record 1340 | itaocara
# Processing record 1341 | redlands
# Processing record 1342 | dudinka
# Processing record 1343 | nybro
# Processing record 1344 | jiroft
# City not found. Skipping...
# Processing record 1345 | nador
# ...
# Processing record 1669 | ayotzintepec
# Processing record 1670 | bisert
# Processing record 1671 | dinsor
# City not found. Skipping...
# Processing record 1672 | conway
# Processing record 1673 | soligalich
# Processing record 1674 | malpe
# Processing record 1675 | crib point
# Processing record 1676 | ratnagiri
# Processing record 1677 | honolulu
# Processing record 1678 | tommot
# Processing record 1679 | mentougou
# Processing record 1680 | mounana
# Processing record 1681 | mao
# Processing record 1682 | sinegorye
# Processing record 1683 | buluang
# Processing record 1684 | khurai
# Processing record 1685 | smoky lake
# Processing record 1686 | ibia
# Processing record 1687 | abancay
# Processing record 1688 | caconda
# Processing record 1689 | mlonggo
# Processing record 1690 | finschhafen
# Processing record 1691 | abha
# Processing record 1692 | ridgecrest
# Processing record 1693 | mirpur sakro
# Processing record 1694 | tripoli
# Processing record 1695 | kalanguy
# Processing record 1696 | puerto colombia
# Processing record 1697 | suifenhe
# Processing record 1698 | yeppoon
# Processing record 1699 | san jose
# Processing record 1700 | bermeo
# Processing record 1701 | basi
# Processing record 1702 | addi ugri
# City not found. Skipping...
# Processing record 1703 | kemin
# Processing record 1704 | san luis
# Processing record 1705 | chernyshkovskiy
# Processing record 1706 | bequimao
# Processing record 1707 | izumo
# Processing record 1708 | haian
# Processing record 1709 | knysna
# Processing record 1710 | bogale
# Processing record 1711 | malazgirt
# Processing record 1712 | chubbuck
# Processing record 1713 | ystad
# Processing record 1714 | mananjary
# Processing record 1715 | pointe-noire
# Processing record 1716 | jagtial
# Processing record 1717 | kazalinsk
# City not found. Skipping...
# Processing record 1718 | turayf
# Processing record 1719 | lugovoy
# Processing record 1720 | cochrane
# Processing record 1721 | aykhal
# Processing record 1722 | bacuit
# City not found. Skipping...
# Processing record 1723 | auki
# Processing record 1724 | areia branca
# Processing record 1725 | chernyshevskiy
# Processing record 1726 | pareora
# Processing record 1727 | bend
# Processing record 1728 | paka
# Processing record 1729 | sarakhs
# Processing record 1730 | felidhoo
# City not found. Skipping...
# Processing record 1731 | conceicao do mato dentro
# Processing record 1732 | terrace
# Processing record 1733 | mezen
# Processing record 1734 | itoman
# Processing record 1735 | tungawan
# Processing record 1736 | japura
# Processing record 1737 | tornio
# Processing record 1738 | peleduy
# Processing record 1739 | fort saint john
# City not found. Skipping...
# Processing record 1740 | thul
# Processing record 1741 | verkhoyansk
# Processing record 1742 | tazovskiy
# Processing record 1743 | tchollire
# Processing record 1744 | nieuw amsterdam
# Processing record 1745 | san antonio de cortes
# Processing record 1746 | tambilil
# Processing record 1747 | yurimaguas
# Processing record 1748 | ubauro
# Processing record 1749 | santa fe
# Processing record 1750 | jubayl
# City not found. Skipping...
# Processing record 1751 | yurga
# Processing record 1752 | barinas
# Processing record 1753 | torrington
# Processing record 1754 | karasjok
# Processing record 1755 | clinton
# Processing record 1756 | onega
# Processing record 1757 | can
# Processing record 1758 | cotonou
# Processing record 1759 | high prairie
# Processing record 1760 | rurrenabaque
# Processing record 1761 | alto baudo
# City not found. Skipping...
# Processing record 1762 | say
# Processing record 1763 | demidov
# Processing record 1764 | kyra
# Processing record 1765 | hukuntsi
# Processing record 1766 | mahalapye
# Processing record 1767 | peruc
# Processing record 1768 | atasu
# Processing record 1769 | puerto ayacucho
# Processing record 1770 | dom pedro
# Processing record 1771 | tongchuan
# Processing record 1772 | daverdisse
# Processing record 1773 | kontagora
# Processing record 1774 | kaka
# Processing record 1775 | kattivakkam
# Processing record 1776 | bayburt
# Processing record 1777 | schwandorf
# Processing record 1778 | valdosta
# Processing record 1779 | palasa
# Processing record 1780 | caraballeda
# Processing record 1781 | kindu
# Processing record 1782 | novikovo
# Processing record 1783 | kankan
# Processing record 1784 | namtsy
# Processing record 1785 | balkanabat
# Processing record 1786 | ranong
# Processing record 1787 | kama
# Processing record 1788 | kotdwara
# Processing record 1789 | maarianhamina
# Processing record 1790 | puerto narino
# Processing record 1791 | logatec
# Processing record 1792 | sonoita
# Processing record 1793 | hanyang
# Processing record 1794 | lazaro cardenas
# Processing record 1795 | torres
# Processing record 1796 | menongue
# Processing record 1797 | buenos aires
# Processing record 1798 | gilgit
# Processing record 1799 | guilin
# Processing record 1800 | cootamundra
# Processing record 1801 | mpika
# Processing record 1802 | bilaspur
# Processing record 1803 | kungurtug
# Processing record 1804 | formosa
# Processing record 1805 | powell
# Processing record 1806 | yabrud
# Processing record 1807 | lasem
# Processing record 1808 | amahai
# Processing record 1809 | boundiali
# Processing record 1810 | okoneshnikovo
# Processing record 1811 | abashiri
# Processing record 1812 | katsiveli
# City not found. Skipping...
# Processing record 1813 | ternate
# Processing record 1814 | korem
# Processing record 1815 | lynchburg
# Processing record 1816 | ronne
# Processing record 1817 | ambon
# Processing record 1818 | baykit
# Processing record 1819 | dutlwe
# Processing record 1820 | limon
# Processing record 1821 | sao joao do piaui
# Processing record 1822 | shelburne
# Processing record 1823 | bestobe
# Processing record 1824 | burns lake
# Processing record 1825 | concordia
# Processing record 1826 | aflao
# Processing record 1827 | bossembele
# City not found. Skipping...
# Processing record 1828 | gorno-chuyskiy
# City not found. Skipping...
# Processing record 1829 | alanya
# Processing record 1830 | la ciotat
# Processing record 1831 | teberda
# Processing record 1832 | road town
# Processing record 1833 | vannes
# Processing record 1834 | ngukurr
# City not found. Skipping...
# Processing record 1835 | mahon
# Processing record 1836 | madingou
# Processing record 1837 | honningsvag
# Processing record 1838 | adjumani
# Processing record 1839 | brigantine
# Processing record 1840 | de-kastri
# Processing record 1841 | helena
# Processing record 1842 | marondera
# Processing record 1843 | iskateley
# Processing record 1844 | dong hoi
# Processing record 1845 | dosso
# Processing record 1846 | hirado
# Processing record 1847 | sugito
# Processing record 1848 | silver city
# Processing record 1849 | mutsamudu
# City not found. Skipping...
# Processing record 1850 | sungaipenuh
# Processing record 1851 | ivanteyevka
# Processing record 1852 | qianguo
# Processing record 1853 | santa cruz de la palma
# Processing record 1854 | madimba
# Processing record 1855 | rawannawi
# City not found. Skipping...
# Processing record 1856 | upata
# Processing record 1857 | el angel
# Processing record 1858 | kuche
# City not found. Skipping...
# Processing record 1859 | port hawkesbury
# Processing record 1860 | kloulklubed
# Processing record 1861 | saravan
# Processing record 1862 | akyab
# Processing record 1863 | san buenaventura
# Processing record 1864 | yarada
# Processing record 1865 | pestovo
# Processing record 1866 | nushki
# Processing record 1867 | blackwater
# Processing record 1868 | kayerkan
# Processing record 1869 | brus laguna
# Processing record 1870 | tauranga
# Processing record 1871 | chenghai
# Processing record 1872 | dyurtyuli
# Processing record 1873 | angoche
# Processing record 1874 | mugur-aksy
# Processing record 1875 | bartica
# Processing record 1876 | wajima
# Processing record 1877 | may pen
# Processing record 1878 | skjervoy
# Processing record 1879 | dhidhdhoo
# Processing record 1880 | ohafia
# Processing record 1881 | tlahualilo
# City not found. Skipping...
# Processing record 1882 | gurgan
# City not found. Skipping...
# Processing record 1883 | berekua
# Processing record 1884 | coracora
# Processing record 1885 | saquena
# Processing record 1886 | dorado
# Processing record 1887 | wuxi
# Processing record 1888 | jiangyou
# Processing record 1889 | narasaraopet
# Processing record 1890 | kapit
# Processing record 1891 | kisaran
# Processing record 1892 | praxedis guerrero
# Processing record 1893 | sarangani
# Processing record 1894 | sindgi
# Processing record 1895 | khonuu
# City not found. Skipping...
# Processing record 1896 | phalombe
# Processing record 1897 | revelstoke
# Processing record 1898 | nueva armenia
# Processing record 1899 | kuito
# Processing record 1900 | kerepehi
# Processing record 1901 | huallanca
# Processing record 1902 | greytown
# Processing record 1903 | itamaraca
# Processing record 1904 | piacabucu
# Processing record 1905 | arnedo
# Processing record 1906 | choszczno
# Processing record 1907 | loreto
# Processing record 1908 | pyshma
# Processing record 1909 | aybak
# City not found. Skipping...
# Processing record 1910 | san jeronimo
# Processing record 1911 | linguere
# Processing record 1912 | mozarlandia
# Processing record 1913 | pemba
# Processing record 1914 | algiers
# Processing record 1915 | maumere
# Processing record 1916 | ayr
# Processing record 1917 | fort william
# Processing record 1918 | kaseda
# Processing record 1919 | kasongo-lunda
# Processing record 1920 | minudasht
# Processing record 1921 | sousa
# Processing record 1922 | redwater
# Processing record 1923 | edd
# Processing record 1924 | carlyle
# Processing record 1925 | mae sai
# Processing record 1926 | freeport
# Processing record 1927 | abrau-dyurso
# Processing record 1928 | doctor pedro p. pena
# City not found. Skipping...
# Processing record 1929 | xihe
# Processing record 1930 | chany
# Processing record 1931 | ust-tsilma
# Processing record 1932 | micheweni
# Processing record 1933 | xingyi
# Processing record 1934 | kaduy
# Processing record 1935 | bahir dar
# Processing record 1936 | mehran
# Processing record 1937 | herrenberg
# Processing record 1938 | hervey bay
# Processing record 1939 | santa isabel
# Processing record 1940 | gaoua
# Processing record 1941 | dutse
# Processing record 1942 | vanimo
# Processing record 1943 | fauske
# Processing record 1944 | rodos
# Processing record 1945 | snezhnogorsk
# Processing record 1946 | teterow
# Processing record 1947 | san joaquin
# Processing record 1948 | peddapalli
# Processing record 1949 | wakkanai
# Processing record 1950 | celestun
# Processing record 1951 | mangrol
# Processing record 1952 | grand centre
# City not found. Skipping...
# Processing record 1953 | tunduru
# City not found. Skipping...
# Processing record 1954 | southampton
# Processing record 1955 | corn island
# Processing record 1956 | kotelnikovo
# Processing record 1957 | san ignacio
# Processing record 1958 | salinas
# Processing record 1959 | tocopilla
# Processing record 1960 | tammisaari
# Processing record 1961 | tome-acu
# City not found. Skipping...
# Processing record 1962 | waounde
# Processing record 1963 | peace river
# Processing record 1964 | lubu
# Processing record 1965 | cocobeach
# Processing record 1966 | minas
# Processing record 1967 | santa lucia
# Processing record 1968 | soure
# Processing record 1969 | kargil
# Processing record 1970 | motril
# Processing record 1971 | farafangana
# Processing record 1972 | newport
# Processing record 1973 | murdochville
# Processing record 1974 | bisira
# Processing record 1975 | oriximina
# Processing record 1976 | san matias
# Processing record 1977 | kerman
# Processing record 1978 | orichi
# Processing record 1979 | magistralnyy
# Processing record 1980 | northam
# Processing record 1981 | holmestrand
# Processing record 1982 | nadapuram
# Processing record 1983 | xapuri
# Processing record 1984 | kroya
# Processing record 1985 | syracuse
# Processing record 1986 | xichang
# Processing record 1987 | puerto cabezas
# Processing record 1988 | kandi
# Processing record 1989 | luohe
# Processing record 1990 | patratu
# City not found. Skipping...
# Processing record 1991 | ariquemes
# Processing record 1992 | las rozas de madrid
# Processing record 1993 | baijiantan
# Processing record 1994 | kanye
# Processing record 1995 | abalak
# Processing record 1996 | havoysund
# Processing record 1997 | nassjo
# Processing record 1998 | astoria
# Processing record 1999 | panaba
# Processing record 2000 | alytus
# Processing record 2001 | san isidro
# Processing record 2002 | bolshoye ignatovo
# City not found. Skipping...
# Processing record 2003 | lambarene
# Processing record 2004 | aleppo
# Processing record 2005 | sorvag
# City not found. Skipping...
# Processing record 2006 | bunawan
# Processing record 2007 | galle
# Processing record 2008 | porbandar
# Processing record 2009 | kuldur
# Processing record 2010 | afmadu
# City not found. Skipping...
# Processing record 2011 | colares
# Processing record 2012 | mattru
# Processing record 2013 | ipameri
# Processing record 2014 | choa saidan shah
# Processing record 2015 | estelle
# Processing record 2016 | kolokani
# Processing record 2017 | draguignan
# Processing record 2018 | kashi
# Processing record 2019 | atbasar
# Processing record 2020 | norwood
# Processing record 2021 | livingston
# Processing record 2022 | saint-francois
# Processing record 2023 | carman
# Processing record 2024 | phalaborwa
# Processing record 2025 | kralendijk
# Processing record 2026 | aktau
# Processing record 2027 | villa corzo
# Processing record 2028 | fougamou
# Processing record 2029 | spasskoye
# Processing record 2030 | mushie
# Processing record 2031 | koulikoro
# Processing record 2032 | karamay
# City not found. Skipping...
# Processing record 2033 | sayyan
# Processing record 2034 | santa maria
# Processing record 2035 | nyandoma
# Processing record 2036 | oxelosund
# Processing record 2037 | kencong
# Processing record 2038 | willmar
# Processing record 2039 | dipkarpaz
# City not found. Skipping...
# Processing record 2040 | natal
# Processing record 2041 | gemena
# Processing record 2042 | marquette
# Processing record 2043 | garissa
# Processing record 2044 | ryazhsk
# Processing record 2045 | la louviere
# Processing record 2046 | san
# Processing record 2047 | miles city
# Processing record 2048 | pathalgaon
# Processing record 2049 | hokitika
# Processing record 2050 | ishigaki
# Processing record 2051 | nagornyy
# Processing record 2052 | puerto cabello
# Processing record 2053 | umm durman
# City not found. Skipping...
# Processing record 2054 | wad madani
# Processing record 2055 | izhma
# Processing record 2056 | orchard homes
# Processing record 2057 | mwanza
# Processing record 2058 | washougal
# Processing record 2059 | mandera
# Processing record 2060 | puerto leguizamo
# Processing record 2061 | jacksonville
# Processing record 2062 | russellville
# Processing record 2063 | port-de-paix
# City not found. Skipping...
# Processing record 2064 | azuaga
# Processing record 2065 | tokur
# Processing record 2066 | marzuq
# Processing record 2067 | suntar
# Processing record 2068 | bratsk
# Processing record 2069 | karaul
# City not found. Skipping...
# Processing record 2070 | barraute
# Processing record 2071 | lashio
# Processing record 2072 | bobovdol
# Processing record 2073 | zheshart
# Processing record 2074 | gangotri
# City not found. Skipping...
# Processing record 2075 | scarborough
# Processing record 2076 | bolshaya chernigovka
# City not found. Skipping...
# Processing record 2077 | moissac
# Processing record 2078 | bambanglipuro
# Processing record 2079 | bichura
# Processing record 2080 | beruni
# City not found. Skipping...
# Processing record 2081 | jinchengjiang
# City not found. Skipping...
# Processing record 2082 | barreiras
# Processing record 2083 | komyshuvakha
# Processing record 2084 | ludvika
# Processing record 2085 | key west
# Processing record 2086 | alamosa
# Processing record 2087 | ankara
# Processing record 2088 | myanaung
# Processing record 2089 | karabulak
# Processing record 2090 | talpa
# Processing record 2091 | muslyumovo
# Processing record 2092 | wittmund
# Processing record 2093 | rajshahi
# Processing record 2094 | general roca
# Processing record 2095 | teahupoo
# Processing record 2096 | luce
# Processing record 2097 | kendari
# Processing record 2098 | yungay
# Processing record 2099 | ghorawal
# Processing record 2100 | ambalavao
# Processing record 2101 | lopez jaena
# Processing record 2102 | borama
# City not found. Skipping...
# Processing record 2103 | vanavara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lon  Max Temp  Humidity  Cloudiness  \
# 0          mataura      NZ -46.1927  168.8643     55.99        92          97
# 1     punta arenas      CL -53.1500  -70.9167     53.60        62          75
# 2         saldanha      ZA -33.0117   17.9442     66.20        77          98
# 3          rikitea      PF -23.1203 -134.9692     78.33        72           2
# 4      east london      ZA -33.0153   27.9116     68.00        94           0
# 5          pitimbu      BR  -7.4706  -34.8086     78.80       100          75
# 6     kruisfontein      ZA -34.0033   24.7314     60.01        94          96
# 7  arraial do cabo      BR -22.9661  -42.0278     84.20        47           0
# 8         taunggyi      MM  20.7833   97.0333     69.98        43          36
# 9           osinki      RU  52.8432   49.5132     53.96        82         100
#
#    Wind Speed Current Description
# 0        1.99     overcast clouds
# 1       13.80       broken clouds
# 2        9.22     overcast clouds
# 3        9.35           clear sky
# 4        2.30           clear sky
# 5        8.05       broken clouds
# 6        1.01     overcast clouds
# 7       18.41           clear sky
# 8        4.65    scattered clouds
# 9        6.29          light rain

# %%
city_data_df.to_csv('Weather_Database/WeatherPy_Database.csv')
